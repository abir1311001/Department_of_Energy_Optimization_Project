# %%
import pandas as pd
import gurobipy as gp
from gurobipy import GRB

# %%
wb = 'model_data.xlsx'

# %%
# Distance matrix d_ij
dist = pd.read_excel(wb, sheet_name='distance', index_col=0)

# %%
sup_df = pd.read_excel(wb, sheet_name='capacity', index_col=0)
cap = sup_df['capacity']
L = 1000

# %%
# Demand-side data
dem_df = pd.read_excel(wb, sheet_name='demand', index_col=0)
demand  = dem_df['demand']           # D_j

# %%
c   = 0.000001           # $ per unit-mile  
TC  = 22_000          # units a truck can haul
B   = 1_500_000       # budget ceiling

# %%
I = dist.index.tolist()    # supply nodes
J = dist.columns.tolist()  # demand nodes

# %%
m = gp.Model('LocationTransport')
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2673805
# Academic license - for non-commercial use only - expires 2026-05-30

# %%
# Decision variables
x = m.addVars(I, J, name='x', lb=0.0)                    # shipped units
z = m.addVars(I, J, vtype=GRB.INTEGER, name='z', lb=0)   # trucks
y = m.addVars(I, vtype=GRB.BINARY, name='y')             # process installed?

# %%
# Objective: minimise total shipping + setup cost
ship_cost = gp.quicksum(c * dist.loc[i, j] * x[i, j] for i in I for j in J)
setup_cost = gp.quicksum(L * y[i] for i in I)
m.setObjective(ship_cost + setup_cost, GRB.MINIMIZE)

# %%
# -----------------------------
# 3. CONSTRAINTS
# -----------------------------
# 3.1 Budget (total spend cannot exceed B)
m.addConstr(ship_cost + setup_cost <= B, name='Budget')

# 3.2 Supplier capacity (only active if y_i = 1)
for i in I:
    m.addConstr(gp.quicksum(x[i, j] for j in J) <= cap[i] * y[i],
                name=f'SupplyCap[{i}]')

# 3.3 Demand satisfaction
for j in J:
    m.addConstr(gp.quicksum(x[i, j] for i in I) >= demand[j],
                name=f'Demand[{j}]')

# 3.4 Truck capacity
for i in I:
    for j in J:
        m.addConstr(x[i, j] <= TC * z[i, j],
                    name=f'TruckCap[{i},{j}]')


m.Params.TimeLimit = 600          # stop after 10 min
#m.Params.MIPGap    = 0.006         # or stop at 2 % gap
#m.Params.Threads   = 0            # all available cores
#m.Params.MIPFocus  = 1            # improve bound, or 2 to find incumbents


# -----------------------------
# 4. SOLVE
# -----------------------------
m.optimize()
# Out:
# Set parameter TimeLimit to value 600
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M4
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Non-default parameters:
# TimeLimit  600
#
# Optimize a model with 70618 rows, 140442 columns and 350842 nonzeros
# Model fingerprint: 0x1b0c055d
# Variable types: 69958 continuous, 70484 integer (526 binary)
# Coefficient statistics:
#   Matrix range     [2e-06, 2e+06]
#   Objective range  [2e-06, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+03, 6e+06]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 221798.98269
# Presolve removed 69958 rows and 69958 columns
# Presolve time: 0.02s
# Presolved: 660 rows, 70484 columns, 210926 nonzeros
# Variable types: 69958 continuous, 526 integer (526 binary)
# Performing another presolve...
# Presolve time: 0.13s
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity      0.0000000e+00      0s
#        1       2181   1.8734442e+13   7.4937767e+04      0s
#        2       2974   1.6454158e+13   8.6376697e+04      0s
#        3       3807   1.3649650e+13   9.6078868e+04      0s
work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 10: 124599 124599 124600 ... 124600
#
# Time limit reached
# Best objective 1.245991177371e+05, best bound 1.245322435916e+05, gap 0.0537%

# %%
# -----------------------------
# 5. REPORT RESULTS
# -----------------------------
if m.SolCount > 0:
    print(f'\nOptimal total cost: ${m.ObjVal:,.2f}')
    print('\nOpened supply nodes:')
    for i in I:
        if y[i].X > 0.5:
            shipped = sum(x[i, j].X for j in J)
            print(f'  {i}: installed (total units shipped {shipped:.1f})')
    print('\nFlows (i -> j):')
    for i in I:
        for j in J:
            if x[i, j].X > 1e-6:  # ignore tiny values
                print(f'  {i} -> {j}: {x[i,j].X:.1f} units, {z[i,j].X} trucks')
# Out:
# Optimal total cost: $124,599.12
#
# Opened supply nodes:
#   origin_1: installed (total units shipped 2000000.0)
#   origin_106: installed (total units shipped 2000000.0)
#   origin_108: installed (total units shipped 2000000.0)
#   origin_110: installed (total units shipped 2000000.0)
#   origin_111: installed (total units shipped 2000000.0)
#   origin_114: installed (total units shipped 2000000.0)
#   origin_133: installed (total units shipped 2000000.0)
#   origin_134: installed (total units shipped 2000000.0)
#   origin_164: installed (total units shipped 2000000.0)
#   origin_165: installed (total units shipped 2000000.0)
#   origin_166: installed (total units shipped 2000000.0)
#   origin_167: installed (total units shipped 2000000.0)
#   origin_168: installed (total units shipped 2000000.0)
#   origin_169: installed (total units shipped 2000000.0)
#   origin_170: installed (total units shipped 2000000.0)
#   origin_171: installed (total units shipped 2000000.0)
#   origin_172: installed (total units shipped 2000000.0)
#   origin_173: installed (total units shipped 2000000.0)
#   origin_174: installed (total units shipped 2000000.0)
#   origin_175: installed (total units shipped 2000000.0)
#   origin_176: installed (total units shipped 2000000.0)
#   origin_177: installed (total units shipped 2000000.0)
#   origin_178: installed (total units shipped 2000000.0)
#   origin_179: installed (total units shipped 2000000.0)
#   origin_180: installed (total units shipped 2000000.0)
#   origin_181: installed (total units shipped 2000000.0)
#   origin_182: installed (total units shipped 2000000.0)
#   origin_183: installed (total units shipped 2000000.0)
#   origin_184: installed (total units shipped 2000000.0)
#   origin_185: installed (total units shipped 2000000.0)
#   origin_194: installed (total units shipped 1875534.0)
#   origin_223: installed (total units shipped 2000000.0)
#   origin_224: installed (total units shipped 2000000.0)
#   origin_225: installed (total units shipped 2000000.0)
#   origin_226: installed (total units shipped 2000000.0)
#   origin_227: installed (total units shipped 2000000.0)
#   origin_228: installed (total units shipped 2000000.0)
#   origin_229: installed (total units shipped 2000000.0)
#   origin_230: installed (total units shipped 2000000.0)
#   origin_231: installed (total units shipped 2000000.0)
#   origin_232: installed (total units shipped 2000000.0)
#   origin_233: installed (total units shipped 2000000.0)
#   origin_234: installed (total units shipped 2000000.0)
#   origin_235: installed (total units shipped 2000000.0)
#   origin_236: installed (total units shipped 2000000.0)
#   origin_237: installed (total units shipped 2000000.0)
#   origin_278: installed (total units shipped 2000000.0)
#   origin_279: installed (total units shipped 2000000.0)
#   origin_280: installed (total units shipped 2000000.0)
#   origin_281: installed (total units shipped 2000000.0)
#   origin_283: installed (total units shipped 2000000.0)
#   origin_284: installed (total units shipped 2000000.0)
#   origin_285: installed (total units shipped 2000000.0)
#   origin_364: installed (total units shipped 2000000.0)
#   origin_366: installed (total units shipped 2000000.0)
#   origin_373: installed (total units shipped 2000000.0)
#   origin_378: installed (total units shipped 2000000.0)
#   origin_383: installed (total units shipped 2000000.0)
#   origin_384: installed (total units shipped 2000000.0)
#   origin_386: installed (total units shipped 2000000.0)
#   origin_387: installed (total units shipped 2000000.0)
#   origin_388: installed (total units shipped 2000000.0)
#   origin_389: installed (total units shipped 2000000.0)
#   origin_391: installed (total units shipped 2000000.0)
#   origin_404: installed (total units shipped 2000000.0)
#   origin_411: installed (total units shipped 2000000.0)
#   origin_412: installed (total units shipped 2000000.0)
#   origin_413: installed (total units shipped 2000000.0)
#   origin_418: installed (total units shipped 2000000.0)
#   origin_419: installed (total units shipped 2000000.0)
#   origin_421: installed (total units shipped 2000000.0)
#   origin_422: installed (total units shipped 2000000.0)
#   origin_427: installed (total units shipped 2000000.0)
#   origin_435: installed (total units shipped 2000000.0)
#   origin_436: installed (total units shipped 2000000.0)
#
# Flows (i -> j):
#   origin_1 -> dest_22: 905799.0 units, 42.0 trucks
#   origin_1 -> dest_23: 318313.8 units, 15.0 trucks
#   origin_1 -> dest_43: 775887.2 units, 36.0 trucks
#   origin_106 -> dest_27: 122700.4 units, 6.0 trucks
#   origin_106 -> dest_63: 698823.0 units, 32.0 trucks
#   origin_106 -> dest_68: 615116.4 units, 28.0 trucks
#   origin_106 -> dest_73: 563360.2 units, 26.0 trucks
#   origin_108 -> dest_32: 642948.6 units, 30.0 trucks
#   origin_108 -> dest_73: 1357051.4 units, 62.0 trucks
#   origin_110 -> dest_24: 1763808.9 units, 81.0 trucks
#   origin_110 -> dest_47: 236191.1 units, 11.0 trucks
#   origin_111 -> dest_24: 2000000.0 units, 91.0 trucks
#   origin_114 -> dest_18: 37211.8 units, 2.0 trucks
#   origin_114 -> dest_20: 302618.6 units, 14.0 trucks
#   origin_114 -> dest_21: 753486.2 units, 35.0 trucks
#   origin_114 -> dest_23: 272656.4 units, 13.0 trucks
#   origin_114 -> dest_36: 277225.9 units, 13.0 trucks
#   origin_114 -> dest_37: 260914.5 units, 12.0 trucks
#   origin_114 -> dest_39: 95886.6 units, 5.0 trucks
#   origin_133 -> dest_65: 452670.5 units, 21.0 trucks
#   origin_133 -> dest_101: 1547329.5 units, 71.0 trucks
#   origin_134 -> dest_4: 243432.7 units, 12.0 trucks
#   origin_134 -> dest_5: 36224.7 units, 2.0 trucks
#   origin_134 -> dest_6: 1720342.5 units, 79.0 trucks
#   origin_164 -> dest_4: 664167.5 units, 31.0 trucks
#   origin_164 -> dest_12: 192488.7 units, 9.0 trucks
#   origin_164 -> dest_13: 633677.1 units, 29.0 trucks
#   origin_164 -> dest_85: 239859.8 units, 11.0 trucks
#   origin_164 -> dest_86: 269806.9 units, 13.0 trucks
#   origin_165 -> dest_10: 2000000.0 units, 91.0 trucks
#   origin_166 -> dest_1: 427391.2 units, 20.0 trucks
#   origin_166 -> dest_4: 774904.2 units, 36.0 trucks
#   origin_166 -> dest_5: 283629.4 units, 13.0 trucks
#   origin_166 -> dest_15: 514075.2 units, 24.0 trucks
#   origin_167 -> dest_0: 1676512.9 units, 77.0 trucks
#   origin_167 -> dest_13: 323487.1 units, 15.0 trucks
#   origin_168 -> dest_9: 1521227.8 units, 70.0 trucks
#   origin_168 -> dest_79: 478772.2 units, 22.0 trucks
#   origin_169 -> dest_16: 1624252.5 units, 74.0 trucks
#   origin_169 -> dest_102: 375747.5 units, 18.0 trucks
#   origin_170 -> dest_10: 633677.1 units, 29.0 trucks
#   origin_170 -> dest_102: 66362.9 units, 4.0 trucks
#   origin_170 -> dest_111: 805873.6 units, 37.0 trucks
#   origin_170 -> dest_116: 494086.4 units, 23.0 trucks
#   origin_171 -> dest_1: 1030728.0 units, 47.0 trucks
#   origin_171 -> dest_9: 477200.4 units, 22.0 trucks
#   origin_171 -> dest_11: 492071.6 units, 23.0 trucks
#   origin_172 -> dest_3: 1870206.2 units, 86.0 trucks
#   origin_172 -> dest_9: 129793.8 units, 6.0 trucks
#   origin_173 -> dest_4: 520731.2 units, 24.0 trucks
#   origin_173 -> dest_10: 299215.5 units, 14.0 trucks
#   origin_173 -> dest_11: 1067107.4 units, 49.0 trucks
#   origin_173 -> dest_76: 112946.0 units, 6.0 trucks
#   origin_174 -> dest_25: 474569.7 units, 22.0 trucks
#   origin_174 -> dest_26: 460175.5 units, 21.0 trucks
#   origin_174 -> dest_84: 186818.0 units, 9.0 trucks
#   origin_174 -> dest_117: 878436.7 units, 40.0 trucks
#   origin_175 -> dest_25: 271618.4 units, 13.0 trucks
#   origin_175 -> dest_26: 1416954.0 units, 65.0 trucks
#   origin_175 -> dest_62: 128497.9 units, 6.0 trucks
#   origin_175 -> dest_77: 182929.6 units, 9.0 trucks
#   origin_176 -> dest_5: 477850.5 units, 22.0 trucks
#   origin_176 -> dest_7: 1306467.1 units, 60.0 trucks
#   origin_176 -> dest_83: 215682.5 units, 10.0 trucks
#   origin_177 -> dest_3: 706789.2 units, 33.0 trucks
#   origin_177 -> dest_103: 1293210.8 units, 59.0 trucks
#   origin_178 -> dest_5: 2000000.0 units, 91.0 trucks
#   origin_179 -> dest_25: 597016.8 units, 28.0 trucks
#   origin_179 -> dest_26: 128497.9 units, 6.0 trucks
#   origin_179 -> dest_62: 1274485.2 units, 58.0 trucks
#   origin_180 -> dest_103: 1575435.1 units, 72.0 trucks
#   origin_180 -> dest_110: 424564.9 units, 20.0 trucks
#   origin_181 -> dest_25: 1458477.1 units, 67.0 trucks
#   origin_181 -> dest_103: 180184.4 units, 9.0 trucks
#   origin_181 -> dest_115: 361338.6 units, 17.0 trucks
#   origin_182 -> dest_25: 2000000.0 units, 91.0 trucks
#   origin_183 -> dest_16: 311161.6 units, 15.0 trucks
#   origin_183 -> dest_25: 1272206.4 units, 58.0 trucks
#   origin_183 -> dest_106: 416631.9 units, 19.0 trucks
#   origin_184 -> dest_77: 623090.5 units, 29.0 trucks
#   origin_184 -> dest_106: 335719.9 units, 16.0 trucks
#   origin_184 -> dest_114: 690920.6 units, 32.0 trucks
#   origin_184 -> dest_119: 350269.0 units, 16.0 trucks
#   origin_185 -> dest_77: 224960.0 units, 11.0 trucks
#   origin_185 -> dest_107: 1775040.0 units, 81.0 trucks
#   origin_194 -> dest_24: 139897.4 units, 7.0 trucks
#   origin_194 -> dest_38: 403703.4 units, 19.0 trucks
#   origin_194 -> dest_48: 577500.3 units, 27.0 trucks
#   origin_194 -> dest_50: 199217.5 units, 10.0 trucks
#   origin_194 -> dest_60: 254538.2 units, 12.0 trucks
#   origin_194 -> dest_99: 143222.2 units, 7.0 trucks
#   origin_194 -> dest_100: 157454.9 units, 8.0 trucks
#   origin_223 -> dest_63: 1145285.8 units, 53.0 trucks
#   origin_223 -> dest_71: 176109.9 units, 9.0 trucks
#   origin_223 -> dest_74: 678604.3 units, 31.0 trucks
#   origin_224 -> dest_29: 86347.1 units, 4.0 trucks
#   origin_224 -> dest_67: 382854.5 units, 18.0 trucks
#   origin_224 -> dest_75: 338364.2 units, 16.0 trucks
#   origin_224 -> dest_101: 676828.9 units, 31.0 trucks
#   origin_224 -> dest_109: 145790.1 units, 7.0 trucks
#   origin_224 -> dest_113: 369815.3 units, 17.0 trucks
#   origin_225 -> dest_28: 324078.4 units, 15.0 trucks
#   origin_225 -> dest_104: 796307.6 units, 37.0 trucks
#   origin_225 -> dest_105: 879614.0 units, 40.0 trucks
#   origin_226 -> dest_29: 400795.8 units, 19.0 trucks
#   origin_226 -> dest_104: 1599204.2 units, 73.0 trucks
#   origin_227 -> dest_64: 315965.3 units, 15.0 trucks
#   origin_227 -> dest_69: 1542711.8 units, 71.0 trucks
#   origin_227 -> dest_70: 141322.9 units, 7.0 trucks
#   origin_228 -> dest_70: 523388.5 units, 24.0 trucks
#   origin_228 -> dest_108: 1476611.5 units, 68.0 trucks
#   origin_229 -> dest_104: 2000000.0 units, 91.0 trucks
#   origin_230 -> dest_105: 2000000.0 units, 91.0 trucks
#   origin_231 -> dest_104: 376771.3 units, 18.0 trucks
#   origin_231 -> dest_108: 968496.2 units, 45.0 trucks
#   origin_231 -> dest_112: 654732.5 units, 30.0 trucks
#   origin_232 -> dest_65: 473030.2 units, 22.0 trucks
#   origin_232 -> dest_107: 82176.5 units, 4.0 trucks
#   origin_232 -> dest_118: 1444793.3 units, 66.0 trucks
#   origin_233 -> dest_64: 55244.1 units, 3.0 trucks
#   origin_233 -> dest_66: 723641.9 units, 33.0 trucks
#   origin_233 -> dest_72: 1221114.0 units, 56.0 trucks
#   origin_234 -> dest_66: 1129186.0 units, 52.0 trucks
#   origin_234 -> dest_74: 870814.0 units, 40.0 trucks
#   origin_235 -> dest_66: 2000000.0 units, 91.0 trucks
#   origin_236 -> dest_64: 2000000.0 units, 91.0 trucks
#   origin_237 -> dest_24: 347856.7 units, 16.0 trucks
#   origin_237 -> dest_94: 1304722.8 units, 60.0 trucks
#   origin_237 -> dest_97: 262591.1 units, 12.0 trucks
#   origin_237 -> dest_98: 84829.5 units, 4.0 trucks
#   origin_278 -> dest_41: 2000000.0 units, 91.0 trucks
#   origin_279 -> dest_41: 1720241.5 units, 79.0 trucks
#   origin_279 -> dest_42: 279758.5 units, 13.0 trucks
#   origin_280 -> dest_82: 887867.8 units, 41.0 trucks
#   origin_280 -> dest_122: 1112132.2 units, 51.0 trucks
#   origin_281 -> dest_40: 138871.0 units, 7.0 trucks
#   origin_281 -> dest_42: 1341762.1 units, 61.0 trucks
#   origin_281 -> dest_45: 519366.9 units, 24.0 trucks
#   origin_283 -> dest_2: 421548.2 units, 20.0 trucks
#   origin_283 -> dest_19: 146173.4 units, 7.0 trucks
#   origin_283 -> dest_82: 654330.6 units, 30.0 trucks
#   origin_283 -> dest_120: 777947.8 units, 36.0 trucks
#   origin_284 -> dest_17: 22150.4 units, 2.0 trucks
#   origin_284 -> dest_18: 691773.0 units, 32.0 trucks
#   origin_284 -> dest_35: 327772.0 units, 15.0 trucks
#   origin_284 -> dest_44: 153450.9 units, 7.0 trucks
#   origin_284 -> dest_46: 2038.2 units, 1.0 trucks
#   origin_284 -> dest_78: 156576.1 units, 8.0 trucks
#   origin_284 -> dest_80: 408166.2 units, 19.0 trucks
#   origin_284 -> dest_81: 191985.1 units, 9.0 trucks
#   origin_284 -> dest_82: 46088.2 units, 3.0 trucks
#   origin_285 -> dest_41: 763540.4 units, 35.0 trucks
#   origin_285 -> dest_42: 306177.3 units, 14.0 trucks
#   origin_285 -> dest_120: 930282.3 units, 43.0 trucks
#   origin_364 -> dest_4: 776902.2 units, 36.0 trucks
#   origin_364 -> dest_14: 542347.5 units, 25.0 trucks
#   origin_364 -> dest_120: 244592.2 units, 12.0 trucks
#   origin_364 -> dest_123: 436158.0 units, 20.0 trucks
#   origin_366 -> dest_8: 282673.9 units, 13.0 trucks
#   origin_366 -> dest_120: 1017199.5 units, 47.0 trucks
#   origin_366 -> dest_121: 700126.6 units, 32.0 trucks
#   origin_373 -> dest_8: 2000000.0 units, 91.0 trucks
#   origin_378 -> dest_31: 626584.9 units, 29.0 trucks
#   origin_378 -> dest_88: 124300.7 units, 6.0 trucks
#   origin_378 -> dest_96: 1249114.4 units, 57.0 trucks
#   origin_383 -> dest_32: 594838.4 units, 28.0 trucks
#   origin_383 -> dest_96: 1405161.6 units, 64.0 trucks
#   origin_384 -> dest_33: 413135.3 units, 19.0 trucks
#   origin_384 -> dest_34: 810908.9 units, 37.0 trucks
#   origin_384 -> dest_89: 775955.8 units, 36.0 trucks
#   origin_386 -> dest_90: 629040.6 units, 29.0 trucks
#   origin_386 -> dest_91: 306772.2 units, 14.0 trucks
#   origin_386 -> dest_93: 164753.6 units, 8.0 trucks
#   origin_386 -> dest_94: 58880.3 units, 3.0 trucks
#   origin_386 -> dest_95: 840553.3 units, 39.0 trucks
#   origin_387 -> dest_33: 810908.9 units, 37.0 trucks
#   origin_387 -> dest_88: 985269.8 units, 45.0 trucks
#   origin_387 -> dest_92: 203821.3 units, 10.0 trucks
#   origin_388 -> dest_30: 1042386.3 units, 48.0 trucks
#   origin_388 -> dest_33: 405401.1 units, 19.0 trucks
#   origin_388 -> dest_34: 547228.7 units, 25.0 trucks
#   origin_388 -> dest_91: 4983.9 units, 1.0 trucks
#   origin_389 -> dest_87: 376858.4 units, 18.0 trucks
#   origin_389 -> dest_94: 1623141.6 units, 74.0 trucks
#   origin_391 -> dest_96: 2000000.0 units, 91.0 trucks
#   origin_404 -> dest_50: 826421.0 units, 38.0 trucks
#   origin_404 -> dest_51: 1173579.0 units, 54.0 trucks
#   origin_411 -> dest_56: 1771440.3 units, 81.0 trucks
#   origin_411 -> dest_58: 228559.7 units, 11.0 trucks
#   origin_412 -> dest_59: 2000000.0 units, 91.0 trucks
#   origin_413 -> dest_56: 1229813.6 units, 56.0 trucks
#   origin_413 -> dest_58: 770186.4 units, 36.0 trucks
#   origin_418 -> dest_49: 165802.6 units, 8.0 trucks
#   origin_418 -> dest_59: 308127.6 units, 15.0 trucks
#   origin_418 -> dest_61: 166735.7 units, 8.0 trucks
#   origin_418 -> dest_125: 483951.5 units, 22.0 trucks
#   origin_418 -> dest_127: 196846.7 units, 9.0 trucks
#   origin_418 -> dest_128: 563302.5 units, 26.0 trucks
#   origin_418 -> dest_129: 115233.4 units, 6.0 trucks
#   origin_419 -> dest_126: 967125.1 units, 44.0 trucks
#   origin_419 -> dest_132: 1032874.9 units, 47.0 trucks
#   origin_421 -> dest_52: 257337.4 units, 12.0 trucks
#   origin_421 -> dest_53: 918582.7 units, 42.0 trucks
#   origin_421 -> dest_54: 134256.2 units, 7.0 trucks
#   origin_421 -> dest_55: 240607.7 units, 11.0 trucks
#   origin_421 -> dest_56: 228559.7 units, 11.0 trucks
#   origin_421 -> dest_57: 220656.3 units, 11.0 trucks
#   origin_422 -> dest_57: 114143.3 units, 6.0 trucks
#   origin_422 -> dest_59: 1885856.7 units, 86.0 trucks
#   origin_427 -> dest_125: 408110.3 units, 19.0 trucks
#   origin_427 -> dest_126: 439031.9 units, 20.0 trucks
#   origin_427 -> dest_130: 1152857.8 units, 53.0 trucks
#   origin_435 -> dest_51: 116227.6 units, 6.0 trucks
#   origin_435 -> dest_58: 1810623.3 units, 83.0 trucks
#   origin_435 -> dest_124: 73149.0 units, 4.0 trucks
#   origin_436 -> dest_56: 1821334.6 units, 83.0 trucks
#   origin_436 -> dest_131: 178665.4 units, 9.0 trucks

# %%
print(f"python")
# Out:
# python

# %%
print(f"what the hell")
# Out:
# what the hell

# %%
print(f"gurobi20")
# Out:
# gurobi20

# %%
print(f"we are the best")
# Out:
# we are the best

# %%
print(f"I am working on it")
print(f"potka re ami valobasi")
print(f"potka")
# Out:
# I am working on it
# potka re ami valobasi
# potka
